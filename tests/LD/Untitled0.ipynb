# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pylab

# %%
run ld_test.py

# %%
param = parameter(nsam = 5, replicate = 1, seqlen = 1e4, rho = 1e-8)

# %%
out = run_program ( param, scrm=False, prefix="msout")
myinfo = process_ms_scrm_output("msout")
# Out:
# { time -p ms 5 1 -T  -r 3.9996 10000.0 > msout ;} 2> time.text

# %%
one_single_rep(param, scrm=False, prefix="msout")
# Out:
# { time -p ms 5 1 -T  -r 3.9996 10000.0 > msout ;} 2> time.text
# ([0.17418391464418406, 0.15687330680610537, 0.1440216771993718],
#  [1.0, 1.0, 1.0])

# %%
# Out:
# FirstCoal         Untitled0.ipynb   msTreeFreq        msoutTreeFreq     scrmoutTreeFreq   testTmrca
# LOG               ld_test.py*       msTrees           msoutTrees        scrmoutTrees      testTreeFreq
# Tmrca             ms                msout             scrmout           seedms            testTrees
# TreeFreq          msFirstCoal       msoutFirstCoal    scrmoutFirstCoal  test
# Trees             msTmrca           msoutTmrca        scrmoutTmrca      testFirstCoal

# %%
pylab.hist(msac[0])
pylab.title("ETMRCA")
pylab.figure()
pylab.hist(msac[1])
pylab.title("ETMRC")
pylab.figure()
pylab.hist(msac[2])
pylab.title("Eclade")

# %%
pylab.hist(scrmac[0])
pylab.title("ETMRCA")
pylab.figure()
pylab.hist(scrmac[1])
pylab.title("ETMRC")
pylab.figure()
pylab.hist(scrmac[2])
pylab.title("Eclade")

# %%
print mean(msac[0])-1.96*std(msac[0])/sqrt(10000), mean(msac[0])+1.96*std(msac[0])/sqrt(10000)
print mean(scrmac[0])-1.96*std(scrmac[0])/sqrt(10000), mean(scrmac[0])+1.96*std(scrmac[0])/sqrt(10000)
# Out:
# 0.93712381457 0.95245748657
# 0.92074541866 0.933899873302

# %%
print mean(msac[1])-1.96*std(msac[1])/sqrt(10000), mean(msac[1])+1.96*std(msac[1])/sqrt(10000)
print mean(scrmac[1])-1.96*std(scrmac[1])/sqrt(10000), mean(scrmac[1])+1.96*std(scrmac[1])/sqrt(10000)
# Out:
# 1.29673001317e-05 1.40559319259e-05
# 1.28237041738e-05 1.38697309843e-05

# %%
print mean(msac[2])-1.96*std(msac[2])/sqrt(10000), mean(msac[2])+1.96*std(msac[2])/sqrt(10000)
print mean(scrmac[2])-1.96*std(scrmac[2])/sqrt(10000), mean(scrmac[2])+1.96*std(scrmac[2])/sqrt(10000)
# Out:
# 0.920394154512 0.925992389933
# 0.970447540803 0.972946641419
